# %% [markdown]
# <a href="https://colab.research.google.com/github/ZhRaF/Ai-training/blob/master/sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
import os

files=files.upload()

# merging 1 year sales
files = [file for file in os.listdir('./') if file.endswith('.csv')]
# this returns file names

# List to store DataFrames
dfs = []

for file in files:
   df = pd.read_csv('./' + file)
  # creating a df from each  file path
   dfs.append(df)


# Concatenate all DataFrames in the list
all_months_data = pd.concat(dfs, ignore_index=True)
# all_months_data.head()

all_months_data.to_csv("year_sales.csv",index=False)

# reading from our file
print("year sales")
year_sales=pd.read_csv("year_sales.csv")
year_sales.head()
# Out:
#      <input type="file" id="files-9da4c5ed-8143-484c-a4c5-1b3f46a48dd6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9da4c5ed-8143-484c-a4c5-1b3f46a48dd6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# data cleaning to get rid of nan valus
nan_df=year_sales[year_sales.isna().any(axis=1)]
# rows that any of their columns are NaN
# axis=1 for checking rows , 0 for columns

# how many nan values are there ?!!
print(len(nan_df))

# how many rows with all culumns are nan values are there ?!!
print(len(year_sales[year_sales.isna().all(axis=1)]))

# deleting them
year_sales=year_sales.dropna(how='all')
nan_df.head()
# Out:
# 545
# 545
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 339       NaN     NaN              NaN        NaN        NaN              NaN
# 630       NaN     NaN              NaN        NaN        NaN              NaN
# 735       NaN     NaN              NaN        NaN        NaN              NaN
# 1136      NaN     NaN              NaN        NaN        NaN              NaN
# 1349      NaN     NaN              NaN        NaN        NaN              NaN

# %%
Or_values=year_sales[year_sales['Order Date'].str[0:2] == 'Or']
print(len(Or_values))
# how many rows with Or in date field


year_sales=year_sales[year_sales['Order Date'].str[0:2] != 'Or']
# deleting them
# Out:
# 355

# %%
# BEST MONTH FOR SALES
# 1ST METHOD

# ADDING MONTH COLUMN
year_sales['month']=year_sales['Order Date'].str[0:2].astype(int)
year_sales.head()

total_price = 0
max_month = 0
max_price = 0

for i in range(1, 13):
    month_sales = year_sales[year_sales['month'] == i]
    order_price = month_sales['Quantity Ordered'].astype(float) * month_sales['Price Each'].astype(float)

    price_month = order_price.sum()
    print(price_month)

    if price_month > max_price:
        max_price = price_month
        max_month = i

print("Month with the maximum sales:", max_month)
print("Total price in that month:", max_price)
# Out:
# 1822256.73
# 2202022.42
# 2807100.38
# 3390670.2399999998
# 3152606.7499999995
# 2577802.26
# 2647775.76
# 2244467.88
# 2097560.13
# 3736726.8799999994
# 3199603.1999999997
# 4613443.339999999
# Month with the maximum sales: 12
# Total price in that month: 4613443.339999999

# %%
# BEST MONTH FOR SALES
# 2ND METHOD
year_sales['sales'] = year_sales['Quantity Ordered'].astype(float) * year_sales['Price Each'].astype(float)
year_sales.groupby('month').sum(numeric_only=True)
# Out:
#             sales
# month
# 1      1822256.73
# 2      2202022.42
# 3      2807100.38
# 4      3390670.24
# 5      3152606.75
# 6      2577802.26
# 7      2647775.76
# 8      2244467.88
# 9      2097560.13
# 10     3736726.88
# 11     3199603.20
# 12     4613443.34
